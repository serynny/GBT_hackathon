# %% [markdown]
# # Import

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip3 install torch
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.4.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer, BertForSequenceClassification, AdamW
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from tqdm import tqdm
import pandas as pd
from types import SimpleNamespace

# %% [markdown]
# # Hyperparameter

# %%
config = {
    "learning_rate": 1e-5,
    "epoch": 20,
    "batch_size": 64,
    "weight_decay": 0.01,
    "dropout_rate": 0.2,
    "warmup_steps": 100,
    "max_grad_norm": 1.0,
    "adam_epsilon": 1e-8
}

CFG = SimpleNamespace(**config)

# %% [markdown]
# # Load Data

# %%
train_df = pd.read_csv("/content/drive/MyDrive/gbt해커톤/data/train.csv")
test_df = pd.read_csv("/content/drive/MyDrive/gbt해커톤//data/test.csv")

# %% [markdown]
# # Load Model

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
tokenizer = BertTokenizer.from_pretrained('monologg/kobert')
model = BertForSequenceClassification.from_pretrained('monologg/kobert', num_labels=len(train_df['분류'].unique())).to(device)
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'KoBertTokenizer'.
# The class this function is called from is 'BertTokenizer'.
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at monologg/kobert and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# # Custom Dataset

# %%
class TextDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len=128):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, item):
        text = str(self.texts[item])
        label = self.labels[item] if self.labels is not None else -1
        encoding = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_len,
            return_token_type_ids=False,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            return_tensors='pt',
        )
        return {
            'text': text,
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'labels': torch.tensor(label, dtype=torch.long)
        }

# %% [markdown]
# # Data Preprocessing

# %%
# # 데이터 준비
# train_df['제목_키워드'] = train_df['제목'] + ' ' + train_df['키워드']
# test_df['제목_키워드'] = test_df['제목'] + ' ' + test_df['키워드']

# %%
# '분류' 열에서 앞부분만 추출하여 '분류_대분류'라는 새로운 열에 저장
train_df['분류_대분류'] = train_df['분류'].apply(lambda x: x.split(':')[0])

# 결과 확인
train_df['분류_대분류'].value_counts()
# Out:
# 분류_대분류
# 지역       26950
# 경제       10534
# 사회        8245
# 정치        2521
# 문화        2500
# 스포츠       2035
# IT_과학     1487
# 국제         337
# Name: count, dtype: int64

# %%
from collections import Counter

def find_common_words_and_remove(num_categories=8, top_n=10, com_counts=10, train_df=train_df, test_df=test_df):
    # '분류_대분류'의 각 범주에 속하는 단어들을 추출
    category_words = {category: [] for category in train_df["분류_대분류"].unique()}

    for category in category_words.keys():
        words = train_df.loc[train_df["분류_대분류"] == category, "키워드"].apply(lambda x: x.split(',')).tolist()
        category_words[category] = [word for sublist in words for word in sublist]

    # 각 범주에 속하는 단어들을 카운팅
    word_counts = {category: Counter(words) for category, words in category_words.items()}

    # 지정된 범주 갯수에 속하는 단어들을 찾기
    '''  이때 범주별 10회 이상 등장한 단어만을 고려 '''
    common_words = set()
    for word in word_counts[list(word_counts.keys())[0]].keys():
        count = sum(1 for category in word_counts.keys() if word in word_counts[category] and word_counts[category][word] >= com_counts)
        if count == num_categories:
            common_words.add(word)

    # 지정된 범주 갯수에 속하는 단어와 그 갯수를 계산
    common_word_counts = {word: sum(word_counts[category][word] for category in word_counts.keys()) for word in common_words}

    # 단어들을 갯수 기준으로 정렬하고 상위 N개를 선택
    top_common_words = sorted(common_word_counts.items(), key=lambda x: x[1], reverse=True)[:top_n]
    print(f"상위 {top_n}개의 단어 확인")

    # 상위 N개의 단어와 그 갯수, 그리고 각 범주에서의 갯수를 출력
    for word, total_count in top_common_words:
        category_counts = {category: word_counts[category][word] for category in word_counts.keys()}
        print(f"단어: {word}, 총 갯수: {total_count}, 각 범주에서의 갯수: {category_counts}")

    # 총 몇 개의 단어가 겹치는지 출력
    print(f"총 {len(common_words)}개의 단어가 겹칩니다.")

    # top_n 기준으로 겹치는 단어들을 '키워드' 열에서 제거하고 새로운 열에 저장
    top_common_words_set = set(word for word, _ in top_common_words)

    def remove_top_common_words(keywords):
        return ', '.join([word for word in keywords.split(',') if word not in top_common_words_set])

    train_df['키워드'] = train_df['키워드'].apply(remove_top_common_words)
    test_df['키워드'] = test_df['키워드'].apply(remove_top_common_words)

# 함수 호출 예시
# find_common_words_and_remove(num_categories=7, top_n=10, com_counts=10)

# %%
find_common_words_and_remove(num_categories=8, top_n=59, com_counts=50)
find_common_words_and_remove(num_categories=7, top_n=51, com_counts=100)
find_common_words_and_remove(num_categories=6, top_n=2, com_counts=500)
# Out:
# 상위 59개의 단어 확인
# 단어: 용인시, 총 갯수: 102752, 각 범주에서의 갯수: {'문화': 4000, '지역': 57286, '국제': 472, '정치': 3871, '경제': 18940, '사회': 12329, '스포츠': 2659, 'IT_과학': 3195}
# 단어: 용인, 총 갯수: 68534, 각 범주에서의 갯수: {'문화': 3417, '지역': 35179, '국제': 272, '정치': 3777, '경제': 19462, '사회': 4054, '스포츠': 1182, 'IT_과학': 1191}
# 단어: 지역, 총 갯수: 52184, 각 범주에서의 갯수: {'문화': 1356, '지역': 28497, '국제': 123, '정치': 3158, '경제': 12855, '사회': 5125, '스포츠': 172, 'IT_과학': 898}
# 단어: 지원, 총 갯수: 51558, 각 범주에서의 갯수: {'문화': 523, '지역': 31031, '국제': 99, '정치': 1729, '경제': 12820, '사회': 4003, '스포츠': 264, 'IT_과학': 1089}
# 단어: 시장, 총 갯수: 48773, 각 범주에서의 갯수: {'문화': 1625, '지역': 25503, '국제': 323, '정치': 4024, '경제': 13296, '사회': 2243, '스포츠': 803, 'IT_과학': 956}
# 단어: 경기도, 총 갯수: 44481, 각 범주에서의 갯수: {'문화': 1265, '지역': 25248, '국제': 124, '정치': 2266, '경제': 9328, '사회': 3918, '스포츠': 1760, 'IT_과학': 572}
# 단어: 경기, 총 갯수: 39922, 각 범주에서의 갯수: {'문화': 1059, '지역': 15621, '국제': 226, '정치': 2266, '경제': 9415, '사회': 7204, '스포츠': 3523, 'IT_과학': 608}
# 단어: 계획, 총 갯수: 34875, 각 범주에서의 갯수: {'문화': 426, '지역': 21520, '국제': 52, '정치': 913, '경제': 9376, '사회': 1814, '스포츠': 116, 'IT_과학': 658}
# 단어: 진행, 총 갯수: 31413, 각 범주에서의 갯수: {'문화': 2178, '지역': 15949, '국제': 87, '정치': 950, '경제': 6314, '사회': 4322, '스포츠': 549, 'IT_과학': 1064}
# 단어: 예정, 총 갯수: 24244, 각 범주에서의 갯수: {'문화': 808, '지역': 11336, '국제': 86, '정치': 650, '경제': 8586, '사회': 2042, '스포츠': 278, 'IT_과학': 458}
# 단어: 기업, 총 갯수: 23042, 각 범주에서의 갯수: {'문화': 131, '지역': 7592, '국제': 150, '정치': 367, '경제': 12928, '사회': 680, '스포츠': 52, 'IT_과학': 1142}
# 단어: 관계자, 총 갯수: 22430, 각 범주에서의 갯수: {'문화': 704, '지역': 11937, '국제': 98, '정치': 590, '경제': 4986, '사회': 3042, '스포츠': 302, 'IT_과학': 771}
# 단어: 서울, 총 갯수: 20886, 각 범주에서의 갯수: {'문화': 907, '지역': 3889, '국제': 52, '정치': 1858, '경제': 8625, '사회': 4920, '스포츠': 445, 'IT_과학': 190}
# 단어: 시민, 총 갯수: 20670, 각 범주에서의 갯수: {'문화': 1123, '지역': 13672, '국제': 53, '정치': 1214, '경제': 2109, '사회': 1545, '스포츠': 202, 'IT_과학': 752}
# 단어: 이날, 총 갯수: 17324, 각 범주에서의 갯수: {'문화': 744, '지역': 7712, '국제': 128, '정치': 1892, '경제': 2320, '사회': 3817, '스포츠': 506, 'IT_과학': 205}
# 단어: 발생, 총 갯수: 16726, 각 범주에서의 갯수: {'문화': 145, '지역': 8932, '국제': 138, '정치': 319, '경제': 1631, '사회': 5141, '스포츠': 71, 'IT_과학': 349}
# 단어: 규모, 총 갯수: 16535, 각 범주에서의 갯수: {'문화': 228, '지역': 6818, '국제': 54, '정치': 381, '경제': 7813, '사회': 786, '스포츠': 68, 'IT_과학': 387}
# 단어: 조사, 총 갯수: 16441, 각 범주에서의 갯수: {'문화': 323, '지역': 6862, '국제': 132, '정치': 730, '경제': 2836, '사회': 5212, '스포츠': 65, 'IT_과학': 281}
# 단어: 코로나19, 총 갯수: 14479, 각 범주에서의 갯수: {'문화': 621, '지역': 6522, '국제': 64, '정치': 251, '경제': 1749, '사회': 4473, '스포츠': 385, 'IT_과학': 414}
# 단어: 관리, 총 갯수: 14333, 각 범주에서의 갯수: {'문화': 177, '지역': 9167, '국제': 57, '정치': 479, '경제': 1683, '사회': 2269, '스포츠': 80, 'IT_과학': 421}
# 단어: 이상일, 총 갯수: 13837, 각 범주에서의 갯수: {'문화': 695, '지역': 8107, '국제': 97, '정치': 835, '경제': 2722, '사회': 706, '스포츠': 383, 'IT_과학': 292}
# 단어: 시작, 총 갯수: 13447, 각 범주에서의 갯수: {'문화': 1204, '지역': 5392, '국제': 73, '정치': 699, '경제': 3228, '사회': 1909, '스포츠': 373, 'IT_과학': 569}
# 단어: 현장, 총 갯수: 12685, 각 범주에서의 갯수: {'문화': 391, '지역': 7219, '국제': 69, '정치': 625, '경제': 1837, '사회': 2115, '스포츠': 68, 'IT_과학': 361}
# 단어: 상황, 총 갯수: 12508, 각 범주에서의 갯수: {'문화': 382, '지역': 4959, '국제': 113, '정치': 797, '경제': 2873, '사회': 2940, '스포츠': 218, 'IT_과학': 226}
# 단어: 용인특례시, 총 갯수: 12326, 각 범주에서의 갯수: {'문화': 546, '지역': 7487, '국제': 77, '정치': 324, '경제': 2517, '사회': 790, '스포츠': 185, 'IT_과학': 400}
# 단어: 확인, 총 갯수: 12257, 각 범주에서의 갯수: {'문화': 548, '지역': 5367, '국제': 106, '정치': 326, '경제': 1939, '사회': 3181, '스포츠': 83, 'IT_과학': 707}
# 단어: 국가, 총 갯수: 11825, 각 범주에서의 갯수: {'문화': 445, '지역': 5460, '국제': 81, '정치': 641, '경제': 4085, '사회': 609, '스포츠': 391, 'IT_과학': 113}
# 단어: 경찰, 총 갯수: 11490, 각 범주에서의 갯수: {'문화': 64, '지역': 2393, '국제': 150, '정치': 373, '경제': 190, '사회': 8097, '스포츠': 144, 'IT_과학': 79}
# 단어: 방문, 총 갯수: 10807, 각 범주에서의 갯수: {'문화': 417, '지역': 5583, '국제': 88, '정치': 840, '경제': 2121, '사회': 1277, '스포츠': 104, 'IT_과학': 377}
# 단어: 차량, 총 갯수: 10242, 각 범주에서의 갯수: {'문화': 129, '지역': 5569, '국제': 58, '정치': 153, '경제': 2146, '사회': 1703, '스포츠': 180, 'IT_과학': 304}
# 단어: 행사, 총 갯수: 9605, 각 범주에서의 갯수: {'문화': 1513, '지역': 4803, '국제': 63, '정치': 456, '경제': 1503, '사회': 898, '스포츠': 132, 'IT_과학': 237}
# 단어: 설명, 총 갯수: 9273, 각 범주에서의 갯수: {'문화': 630, '지역': 3301, '국제': 97, '정치': 638, '경제': 2597, '사회': 1574, '스포츠': 124, 'IT_과학': 312}
# 단어: 사진, 총 갯수: 8580, 각 범주에서의 갯수: {'문화': 944, '지역': 3698, '국제': 101, '정치': 478, '경제': 1494, '사회': 1230, '스포츠': 304, 'IT_과학': 331}
# 단어: 만큼, 총 갯수: 8371, 각 범주에서의 갯수: {'문화': 316, '지역': 3896, '국제': 51, '정치': 440, '경제': 2517, '사회': 815, '스포츠': 183, 'IT_과학': 153}
# 단어: 이동, 총 갯수: 8316, 각 범주에서의 갯수: {'문화': 132, '지역': 4204, '국제': 93, '정치': 201, '경제': 2681, '사회': 722, '스포츠': 79, 'IT_과학': 204}
# 단어: 세계, 총 갯수: 7445, 각 범주에서의 갯수: {'문화': 783, '지역': 1426, '국제': 111, '정치': 269, '경제': 3855, '사회': 271, '스포츠': 368, 'IT_과학': 362}
# 단어: 사고, 총 갯수: 7364, 각 범주에서의 갯수: {'문화': 177, '지역': 3709, '국제': 116, '정치': 95, '경제': 482, '사회': 2585, '스포츠': 79, 'IT_과학': 121}
# 단어: 준비, 총 갯수: 6738, 각 범주에서의 갯수: {'문화': 797, '지역': 2877, '국제': 86, '정치': 362, '경제': 1377, '사회': 762, '스포츠': 301, 'IT_과학': 176}
# 단어: 생각, 총 갯수: 6681, 각 범주에서의 갯수: {'문화': 905, '지역': 1962, '국제': 82, '정치': 920, '경제': 957, '사회': 1365, '스포츠': 383, 'IT_과학': 107}
# 단어: 사람, 총 갯수: 6648, 각 범주에서의 갯수: {'문화': 1032, '지역': 1771, '국제': 79, '정치': 688, '경제': 847, '사회': 1926, '스포츠': 93, 'IT_과학': 212}
# 단어: 결정, 총 갯수: 6171, 각 범주에서의 갯수: {'문화': 123, '지역': 2914, '국제': 54, '정치': 459, '경제': 1450, '사회': 1036, '스포츠': 61, 'IT_과학': 74}
# 단어: 대한민국, 총 갯수: 5796, 각 범주에서의 갯수: {'문화': 1054, '지역': 2207, '국제': 62, '정치': 662, '경제': 1238, '사회': 167, '스포츠': 306, 'IT_과학': 100}
# 단어: 감사, 총 갯수: 5745, 각 범주에서의 갯수: {'문화': 473, '지역': 3496, '국제': 80, '정치': 356, '경제': 454, '사회': 572, '스포츠': 250, 'IT_과학': 64}
# 단어: 한국, 총 갯수: 5701, 각 범주에서의 갯수: {'문화': 1016, '지역': 937, '국제': 337, '정치': 291, '경제': 1717, '사회': 528, '스포츠': 657, 'IT_과학': 218}
# 단어: 상태, 총 갯수: 5642, 각 범주에서의 갯수: {'문화': 183, '지역': 2240, '국제': 58, '정치': 260, '경제': 794, '사회': 1863, '스포츠': 108, 'IT_과학': 136}
# 단어: 성장, 총 갯수: 5387, 각 범주에서의 갯수: {'문화': 192, '지역': 2211, '국제': 73, '정치': 248, '경제': 2054, '사회': 341, '스포츠': 81, 'IT_과학': 187}
# 단어: 모습, 총 갯수: 5385, 각 범주에서의 갯수: {'문화': 963, '지역': 1644, '국제': 131, '정치': 330, '경제': 916, '사회': 1012, '스포츠': 289, 'IT_과학': 100}
# 단어: 정도, 총 갯수: 5357, 각 범주에서의 갯수: {'문화': 455, '지역': 1614, '국제': 64, '정치': 333, '경제': 1399, '사회': 1240, '스포츠': 151, 'IT_과학': 101}
# 단어: 사실, 총 갯수: 5076, 각 범주에서의 갯수: {'문화': 238, '지역': 1520, '국제': 78, '정치': 625, '경제': 742, '사회': 1733, '스포츠': 75, 'IT_과학': 65}
# 단어: 에버랜드, 총 갯수: 4074, 각 범주에서의 갯수: {'문화': 874, '지역': 1291, '국제': 342, '정치': 73, '경제': 759, '사회': 398, '스포츠': 184, 'IT_과학': 153}
# 단어: 사랑, 총 갯수: 3881, 각 범주에서의 갯수: {'문화': 860, '지역': 2063, '국제': 61, '정치': 111, '경제': 344, '사회': 226, '스포츠': 128, 'IT_과학': 88}
# 단어: 자신, 총 갯수: 3856, 각 범주에서의 갯수: {'문화': 574, '지역': 655, '국제': 51, '정치': 457, '경제': 313, '사회': 1552, '스포츠': 180, 'IT_과학': 74}
# 단어: 미국, 총 갯수: 3650, 각 범주에서의 갯수: {'문화': 215, '지역': 252, '국제': 158, '정치': 183, '경제': 2103, '사회': 386, '스포츠': 98, 'IT_과학': 255}
# 단어: 해외, 총 갯수: 3427, 각 범주에서의 갯수: {'문화': 185, '지역': 510, '국제': 80, '정치': 89, '경제': 1667, '사회': 598, '스포츠': 51, 'IT_과학': 247}
# 단어: 행복, 총 갯수: 3330, 각 범주에서의 갯수: {'문화': 453, '지역': 1590, '국제': 53, '정치': 185, '경제': 404, '사회': 540, '스포츠': 55, 'IT_과학': 50}
# 단어: 사이, 총 갯수: 3044, 각 범주에서의 갯수: {'문화': 241, '지역': 1004, '국제': 68, '정치': 151, '경제': 615, '사회': 838, '스포츠': 63, 'IT_과학': 64}
# 단어: 중국, 총 갯수: 2893, 각 범주에서의 갯수: {'문화': 301, '지역': 299, '국제': 846, '정치': 83, '경제': 849, '사회': 379, '스포츠': 63, 'IT_과학': 73}
# 단어: 국제, 총 갯수: 1979, 각 범주에서의 갯수: {'문화': 187, '지역': 812, '국제': 56, '정치': 112, '경제': 464, '사회': 206, '스포츠': 67, 'IT_과학': 75}
# 단어: 일본, 총 갯수: 1869, 각 범주에서의 갯수: {'문화': 225, '지역': 210, '국제': 96, '정치': 89, '경제': 737, '사회': 280, '스포츠': 139, 'IT_과학': 93}
# 총 59개의 단어가 겹칩니다.
# 상위 51개의 단어 확인
# 단어:  도시, 총 갯수: 26921, 각 범주에서의 갯수: {'문화': 469, '지역': 18436, '국제': 154, '정치': 1349, '경제': 5129, '사회': 1091, '스포츠': 43, 'IT_과학': 250}
# 단어:  운영, 총 갯수: 26495, 각 범주에서의 갯수: {'문화': 1171, '지역': 14609, '국제': 36, '정치': 641, '경제': 4857, '사회': 3757, '스포츠': 228, 'IT_과학': 1196}
# 단어:  대상, 총 갯수: 20755, 각 범주에서의 갯수: {'문화': 798, '지역': 11676, '국제': 41, '정치': 583, '경제': 3910, '사회': 2740, '스포츠': 201, 'IT_과학': 806}
# 단어:  센터, 총 갯수: 17850, 각 범주에서의 갯수: {'문화': 248, '지역': 10044, '국제': 40, '정치': 211, '경제': 3954, '사회': 2190, '스포츠': 324, 'IT_과학': 839}
# 단어:  마련, 총 갯수: 17738, 각 범주에서의 갯수: {'문화': 962, '지역': 10148, '국제': 36, '정치': 708, '경제': 3697, '사회': 1566, '스포츠': 131, 'IT_과학': 490}
# 단어:  제공, 총 갯수: 17180, 각 범주에서의 갯수: {'문화': 749, '지역': 7918, '국제': 46, '정치': 462, '경제': 4266, '사회': 2144, '스포츠': 196, 'IT_과학': 1399}
# 단어:  정부, 총 갯수: 16084, 각 범주에서의 갯수: {'문화': 187, '지역': 5560, '국제': 130, '정치': 1953, '경제': 6353, '사회': 1689, '스포츠': 6, 'IT_과학': 206}
# 단어:  선정, 총 갯수: 15941, 각 범주에서의 갯수: {'문화': 537, '지역': 11030, '국제': 14, '정치': 182, '경제': 2677, '사회': 917, '스포츠': 159, 'IT_과학': 425}
# 단어:  참여, 총 갯수: 15651, 각 범주에서의 갯수: {'문화': 1183, '지역': 8692, '국제': 34, '정치': 509, '경제': 2726, '사회': 1827, '스포츠': 130, 'IT_과학': 550}
# 단어:  대표, 총 갯수: 14579, 각 범주에서의 갯수: {'문화': 1016, '지역': 4411, '국제': 43, '정치': 3203, '경제': 3086, '사회': 1375, '스포츠': 902, 'IT_과학': 543}
# 단어:  시민들, 총 갯수: 14484, 각 범주에서의 갯수: {'문화': 1165, '지역': 9173, '국제': 22, '정치': 645, '경제': 1374, '사회': 1174, '스포츠': 148, 'IT_과학': 783}
# 단어:  전국, 총 갯수: 13449, 각 범주에서의 갯수: {'문화': 562, '지역': 5212, '국제': 27, '정치': 669, '경제': 3967, '사회': 2069, '스포츠': 678, 'IT_과학': 265}
# 단어:  가능, 총 갯수: 13278, 각 범주에서의 갯수: {'문화': 474, '지역': 5256, '국제': 35, '정치': 473, '경제': 4724, '사회': 1503, '스포츠': 135, 'IT_과학': 678}
# 단어:  추가, 총 갯수: 12669, 각 범주에서의 갯수: {'문화': 155, '지역': 6355, '국제': 30, '정치': 362, '경제': 2015, '사회': 3311, '스포츠': 156, 'IT_과학': 285}
# 단어:  노력, 총 갯수: 12086, 각 범주에서의 갯수: {'문화': 447, '지역': 7067, '국제': 35, '정치': 657, '경제': 2052, '사회': 1240, '스포츠': 248, 'IT_과학': 340}
# 단어:  활동, 총 갯수: 11499, 각 범주에서의 갯수: {'문화': 838, '지역': 6407, '국제': 25, '정치': 711, '경제': 1219, '사회': 1908, '스포츠': 142, 'IT_과학': 249}
# 단어:  특례시, 총 갯수: 11489, 각 범주에서의 갯수: {'문화': 237, '지역': 6780, '국제': 14, '정치': 2407, '경제': 1333, '사회': 431, '스포츠': 115, 'IT_과학': 172}
# 단어:  결과, 총 갯수: 10715, 각 범주에서의 갯수: {'문화': 222, '지역': 4841, '국제': 45, '정치': 679, '경제': 2006, '사회': 2309, '스포츠': 201, 'IT_과학': 412}
# 단어:  평가, 총 갯수: 10219, 각 범주에서의 갯수: {'문화': 277, '지역': 5454, '국제': 33, '정치': 409, '경제': 2701, '사회': 923, '스포츠': 103, 'IT_과학': 319}
# 단어:  발전, 총 갯수: 9972, 각 범주에서의 갯수: {'문화': 343, '지역': 5910, '국제': 30, '정치': 852, '경제': 2166, '사회': 359, '스포츠': 182, 'IT_과학': 130}
# 단어:  구성, 총 갯수: 9873, 각 범주에서의 갯수: {'문화': 462, '지역': 5273, '국제': 17, '정치': 501, '경제': 2582, '사회': 743, '스포츠': 100, 'IT_과학': 195}
# 단어:  기흥구, 총 갯수: 9806, 각 범주에서의 갯수: {'문화': 303, '지역': 6069, '국제': 25, '정치': 266, '경제': 1750, '사회': 1042, '스포츠': 109, 'IT_과학': 242}
# 단어:  생활, 총 갯수: 9495, 각 범주에서의 갯수: {'문화': 405, '지역': 5260, '국제': 49, '정치': 223, '경제': 1562, '사회': 1596, '스포츠': 195, 'IT_과학': 205}
# 단어:  특례, 총 갯수: 9470, 각 범주에서의 갯수: {'문화': 235, '지역': 5676, '국제': 44, '정치': 1541, '경제': 1405, '사회': 287, '스포츠': 162, 'IT_과학': 120}
# 단어:  포함, 총 갯수: 9328, 각 범주에서의 갯수: {'문화': 255, '지역': 4884, '국제': 45, '정치': 535, '경제': 2185, '사회': 1116, '스포츠': 106, 'IT_과학': 202}
# 단어:  개최, 총 갯수: 8819, 각 범주에서의 갯수: {'문화': 936, '지역': 5014, '국제': 13, '정치': 458, '경제': 1309, '사회': 500, '스포츠': 408, 'IT_과학': 181}
# 단어:  기간, 총 갯수: 8442, 각 범주에서의 갯수: {'문화': 249, '지역': 3818, '국제': 41, '정치': 315, '경제': 2391, '사회': 1279, '스포츠': 106, 'IT_과학': 243}
# 단어:  회장, 총 갯수: 8147, 각 범주에서의 갯수: {'문화': 453, '지역': 3083, '국제': 19, '정치': 730, '경제': 2489, '사회': 999, '스포츠': 262, 'IT_과학': 112}
# 단어:  위치, 총 갯수: 8141, 각 범주에서의 갯수: {'문화': 461, '지역': 3121, '국제': 29, '정치': 180, '경제': 3009, '사회': 609, '스포츠': 462, 'IT_과학': 270}
# 단어:  Yongin, 총 갯수: 8116, 각 범주에서의 갯수: {'문화': 346, '지역': 5598, '국제': 8, '정치': 316, '경제': 838, '사회': 518, '스포츠': 208, 'IT_과학': 284}
# 단어:  내년, 총 갯수: 7972, 각 범주에서의 갯수: {'문화': 165, '지역': 4651, '국제': 47, '정치': 358, '경제': 1828, '사회': 561, '스포츠': 173, 'IT_과학': 189}
# 단어:  참석, 총 갯수: 7478, 각 범주에서의 갯수: {'문화': 334, '지역': 3959, '국제': 41, '정치': 697, '경제': 1462, '사회': 714, '스포츠': 159, 'IT_과학': 112}
# 단어:  기록, 총 갯수: 7121, 각 범주에서의 갯수: {'문화': 333, '지역': 1303, '국제': 26, '정치': 257, '경제': 3050, '사회': 1163, '스포츠': 851, 'IT_과학': 138}
# 단어:  지난달, 총 갯수: 6785, 각 범주에서의 갯수: {'문화': 180, '지역': 2468, '국제': 44, '정치': 305, '경제': 1819, '사회': 1688, '스포츠': 122, 'IT_과학': 159}
# 단어:  관심, 총 갯수: 6653, 각 범주에서의 갯수: {'문화': 430, '지역': 2385, '국제': 46, '정치': 369, '경제': 2490, '사회': 594, '스포츠': 127, 'IT_과학': 212}
# 단어:  자리, 총 갯수: 6282, 각 범주에서의 갯수: {'문화': 542, '지역': 2541, '국제': 27, '정치': 655, '경제': 1521, '사회': 680, '스포츠': 212, 'IT_과학': 104}
# 단어:  전달, 총 갯수: 5954, 각 범주에서의 갯수: {'문화': 259, '지역': 3740, '국제': 45, '정치': 251, '경제': 676, '사회': 723, '스포츠': 136, 'IT_과학': 124}
# 단어:  번역, 총 갯수: 5555, 각 범주에서의 갯수: {'문화': 246, '지역': 3772, '국제': 11, '정치': 191, '경제': 559, '사회': 400, '스포츠': 101, 'IT_과학': 275}
# 단어:  도움, 총 갯수: 5507, 각 범주에서의 갯수: {'문화': 248, '지역': 2978, '국제': 30, '정치': 139, '경제': 962, '사회': 829, '스포츠': 115, 'IT_과학': 206}
# 단어:  City, 총 갯수: 5324, 각 범주에서의 갯수: {'문화': 167, '지역': 3838, '국제': 10, '정치': 208, '경제': 492, '사회': 292, '스포츠': 148, 'IT_과학': 169}
# 단어:  공개, 총 갯수: 4821, 각 범주에서의 갯수: {'문화': 509, '지역': 1306, '국제': 151, '정치': 457, '경제': 976, '사회': 1196, '스포츠': 37, 'IT_과학': 189}
# 단어:  최선, 총 갯수: 4472, 각 범주에서의 갯수: {'문화': 123, '지역': 2717, '국제': 6, '정치': 256, '경제': 664, '사회': 392, '스포츠': 195, 'IT_과학': 119}
# 단어:  방식, 총 갯수: 4368, 각 범주에서의 갯수: {'문화': 212, '지역': 1861, '국제': 25, '정치': 278, '경제': 1057, '사회': 520, '스포츠': 118, 'IT_과학': 297}
# 단어:  기회, 총 갯수: 4179, 각 범주에서의 갯수: {'문화': 365, '지역': 1928, '국제': 17, '정치': 207, '경제': 951, '사회': 408, '스포츠': 155, 'IT_과학': 148}
# 단어:  , 총 갯수: 3958, 각 범주에서의 갯수: {'문화': 148, '지역': 2208, '국제': 15, '정치': 191, '경제': 799, '사회': 317, '스포츠': 178, 'IT_과학': 102}
# 단어:  용인시청, 총 갯수: 3521, 각 범주에서의 갯수: {'문화': 128, '지역': 2117, '국제': 18, '정치': 135, '경제': 421, '사회': 300, '스포츠': 300, 'IT_과학': 102}
# 단어:  선택, 총 갯수: 3100, 각 범주에서의 갯수: {'문화': 248, '지역': 910, '국제': 16, '정치': 261, '경제': 727, '사회': 644, '스포츠': 146, 'IT_과학': 148}
# 단어:  개인, 총 갯수: 3088, 각 범주에서의 갯수: {'문화': 170, '지역': 1349, '국제': 21, '정치': 167, '경제': 515, '사회': 451, '스포츠': 117, 'IT_과학': 298}
# 단어:  경험, 총 갯수: 2924, 각 범주에서의 갯수: {'문화': 362, '지역': 833, '국제': 16, '정치': 242, '경제': 778, '사회': 356, '스포츠': 122, 'IT_과학': 215}
# 단어:  마지막, 총 갯수: 2661, 각 범주에서의 갯수: {'문화': 469, '지역': 754, '국제': 107, '정치': 175, '경제': 496, '사회': 339, '스포츠': 282, 'IT_과학': 39}
# 단어:  공식, 총 갯수: 2097, 각 범주에서의 갯수: {'문화': 178, '지역': 810, '국제': 29, '정치': 207, '경제': 445, '사회': 125, '스포츠': 106, 'IT_과학': 197}
# 총 51개의 단어가 겹칩니다.
# 상위 2개의 단어 확인
# 단어:   사업, 총 갯수: 52397, 각 범주에서의 갯수: {'문화': 558, '지역': 35868, '국제': 20, '정치': 1096, '경제': 11134, '사회': 2669, '스포츠': 33, 'IT_과학': 1019}
# 단어:   교육, 총 갯수: 19085, 각 범주에서의 갯수: {'문화': 666, '지역': 8379, '국제': 17, '정치': 528, '경제': 2821, '사회': 5667, '스포츠': 46, 'IT_과학': 961}
# 총 2개의 단어가 겹칩니다.

# %%
from collections import Counter

def count_and_remove_low_occurrence_keywords(train_df, test_df, threshold=3):
    # '키워드' 열의 각 값을 쉼표로 분리하여 리스트로 변환
    train_df['키워드_리스트'] = train_df['키워드'].apply(lambda x: x.split(','))
    test_df['키워드_리스트'] = test_df['키워드'].apply(lambda x: x.split(','))

    # '분류_대분류' 별로 단어들을 추출하고 카운팅
    category_keywords = {category: [] for category in train_df["분류_대분류"].unique()}

    for category in category_keywords.keys():
        words = train_df.loc[train_df["분류_대분류"] == category, "키워드_리스트"].tolist()
        category_keywords[category] = [word.strip() for sublist in words for word in sublist]

    # 각 '분류_대분류' 별로 단어들을 카운팅하고 단어가 threshold 이하로 존재하는 경우를 찾기
    low_occurrence_words = set()
    for category, words in category_keywords.items():
        word_counts = Counter(words)
        low_occurrence_words.update({word for word, count in word_counts.items() if count <= threshold})

    # 단어가 threshold 이하로 존재하는 경우를 '키워드' 열에서 제거
    def remove_low_occurrence_words(keywords):
        return ', '.join([word.strip() for word in keywords.split(',') if word.strip() not in low_occurrence_words])

    train_df['키워드'] = train_df['키워드'].apply(remove_low_occurrence_words)

    # test_df에서도 동일한 단어를 제거
    def remove_low_occurrence_words_from_test(keywords):
        return ', '.join([word.strip() for word in keywords.split(',') if word.strip() not in low_occurrence_words])

    test_df['키워드'] = test_df['키워드'].apply(remove_low_occurrence_words_from_test)

    # 제거 후 각 '분류_대분류' 별로 하위 10개의 단어와 그 갯수를 출력
    for category in category_keywords.keys():
        words = train_df.loc[train_df["분류_대분류"] == category, "키워드"].apply(lambda x: x.split(',')).tolist()
        words = [word.strip() for sublist in words for word in sublist]
        word_counts = Counter(words)
        bottom_keywords = word_counts.most_common()[:-11:-1]
        print(f"분류_대분류: {category}")
        for word, count in bottom_keywords:
            print(f"  단어: {word}, 갯수: {count}")
        print()

# 함수 호출 예시
# count_and_remove_low_occurrence_keywords(train_df, test_df, threshold=2)

# %%
count_and_remove_low_occurrence_keywords(train_df, test_df, threshold=2)
# Out:
# 분류_대분류: 문화
#   단어: , 갯수: 1
#   단어: 대상어, 갯수: 3
#   단어: 우서일절, 갯수: 3
#   단어: 오수경, 갯수: 3
#   단어: 칠순잔치, 갯수: 3
#   단어: 서병덕, 갯수: 3
#   단어: 김옹, 갯수: 3
#   단어: Docs, 갯수: 3
#   단어: 위작, 갯수: 3
#   단어: 용자봉, 갯수: 3
#
# 분류_대분류: 지역
#   단어: 000건, 갯수: 3
#   단어: So-ro, 갯수: 3
#   단어: 온세미, 갯수: 3
#   단어: 모멘트, 갯수: 3
#   단어: 통합데이터센터, 갯수: 3
#   단어: 통합데이터, 갯수: 3
#   단어: 임의장, 갯수: 3
#   단어: 강서대, 갯수: 3
#   단어: 닭칼국수, 갯수: 3
#   단어: 요금군, 갯수: 3
#
# 분류_대분류: 국제
#   단어: 낭비, 갯수: 3
#   단어: 조선인, 갯수: 3
#   단어: 트럼프행정부, 갯수: 3
#   단어: 아시아인들, 갯수: 3
#   단어: 주씨, 갯수: 3
#   단어: 호감도, 갯수: 3
#   단어: 따오기, 갯수: 3
#   단어: 윌리엄슨카운티, 갯수: 3
#   단어: 패어펙스카운티, 갯수: 3
#   단어: 오세올라카운티, 갯수: 3
#
# 분류_대분류: 정치
#   단어: 법률비서관, 갯수: 3
#   단어: 2교시, 갯수: 3
#   단어: 총괄부위원장, 갯수: 3
#   단어: 열병식, 갯수: 3
#   단어: 전봉학, 갯수: 3
#   단어: 지방지, 갯수: 3
#   단어: 수원갈비, 갯수: 3
#   단어: 일탈행동, 갯수: 3
#   단어: bureaus, 갯수: 3
#   단어: notice, 갯수: 3
#
# 분류_대분류: 경제
#   단어: , 갯수: 1
#   단어: 강만희, 갯수: 3
#   단어: 갓슬라, 갯수: 3
#   단어: 배민라이더스, 갯수: 3
#   단어: 파워콜, 갯수: 3
#   단어: 겨울옷, 갯수: 3
#   단어: 점박이물범, 갯수: 3
#   단어: 개선율, 갯수: 3
#   단어: 철산자이더헤리티지, 갯수: 3
#   단어: 고립은둔청년, 갯수: 3
#
# 분류_대분류: 사회
#   단어: , 갯수: 2
#   단어: 말벌, 갯수: 3
#   단어: 숙행, 갯수: 3
#   단어: 혼획, 갯수: 3
#   단어: 최영함, 갯수: 3
#   단어: 반가사유상, 갯수: 3
#   단어: 창포물, 갯수: 3
#   단어: 여름꽃, 갯수: 3
#   단어: 크린스카이, 갯수: 3
#   단어: 실무사, 갯수: 3
#
# 분류_대분류: 스포츠
#   단어: , 갯수: 2
#   단어: 골볼, 갯수: 3
#   단어: 스퀴즈맥주, 갯수: 3
#   단어: 대한당구연맹, 갯수: 3
#   단어: 1024명, 갯수: 3
#   단어: 천안당구연맹, 갯수: 3
#   단어: 군수기, 갯수: 3
#   단어: 유기적, 갯수: 3
#   단어: 외곽, 갯수: 3
#   단어: 강이슬, 갯수: 3
#
# 분류_대분류: IT_과학
#   단어: 뉴스케일파워, 갯수: 3
#   단어: 권선구청, 갯수: 3
#   단어: 50W, 갯수: 3
#   단어: 보안등, 갯수: 3
#   단어: 방송기능, 갯수: 3
#   단어: 관제요원, 갯수: 3
#   단어: 비극, 갯수: 3
#   단어: 간병살인, 갯수: 3
#   단어: 직매장, 갯수: 3
#   단어: Ombudsperson, 갯수: 3

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54609 entries, 0 to 54608
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       54609 non-null  object
#  1   분류       54609 non-null  object
#  2   제목       54609 non-null  object
#  3   키워드      54609 non-null  object
#  4   분류_대분류   54609 non-null  object
#  5   키워드_리스트  54609 non-null  object
# dtypes: object(6)
# memory usage: 2.5+ MB

# %%
train_df.drop(columns=['제목', '분류_대분류', '키워드_리스트'], inplace=True)
test_df.drop(columns=['제목', '키워드_리스트'], inplace=True)

# %%
# 레이블 인코딩
label_encoder = {label: i for i, label in enumerate(train_df['분류'].unique())}
train_df['label'] = train_df['분류'].map(label_encoder)

# 데이터 분할 (train -> train + validation)
train_df, val_df = train_test_split(train_df, test_size=0.2, stratify=train_df['분류'], random_state=42)

# 데이터셋 생성
train_dataset = TextDataset(train_df.키워드.tolist(), train_df.label.tolist(), tokenizer)
val_dataset = TextDataset(val_df.키워드.tolist(), val_df.label.tolist(), tokenizer)
test_dataset = TextDataset(test_df.키워드.tolist(), None, tokenizer)  # 라벨 없음

# 데이터 로더 생성
train_loader = DataLoader(train_dataset, batch_size=CFG.batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=CFG.batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=CFG.batch_size, shuffle=False)

# %%
# 옵티마이저 및 학습 파라미터 설정
optimizer = AdamW(model.parameters(), lr=CFG.learning_rate)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
# 학습
model.train()
best_f1 = 0.0
patience = 2  # 성능 향상이 없을 때 기다리는 에포크 수
patience_counter = 0

for epoch in range(CFG.epoch):
    for batch in tqdm(train_loader, desc=f'Epoch {epoch + 1}/{CFG.epoch}'):
        optimizer.zero_grad()
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)
        outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        loss.backward()
        optimizer.step()

    # Validation
    model.eval()
    val_predictions = []
    val_true_labels = []
    with torch.no_grad():
        for batch in tqdm(val_loader, desc='Validating'):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)
            outputs = model(input_ids, attention_mask=attention_mask)
            _, preds = torch.max(outputs.logits, dim=1)
            val_predictions.extend(preds.cpu().tolist())
            val_true_labels.extend(labels.cpu().tolist())

    # 검증 결과 출력
    val_f1 = f1_score(val_true_labels, val_predictions, average='macro')
    print(f"Validation F1 Score: {val_f1:.2f}")

    # 조기 종료 체크
    if val_f1 > best_f1:
        best_f1 = val_f1
        patience_counter = 0  # 성능 향상이 있었으므로 카운터 초기화
        # 모델 저장 등 추가 작업을 여기서 수행할 수 있습니다.
    else:
        patience_counter += 1

    # patience 초과 시 학습 종료
    if patience_counter >= patience:
        print("Early stopping triggered.")
        break
# Out:
# Epoch 1/20: 100%|██████████| 683/683 [15:01<00:00,  1.32s/it]
# Validating: 100%|██████████| 171/171 [01:26<00:00,  1.97it/s]
# Validation F1 Score: 0.12
# Epoch 2/20: 100%|██████████| 683/683 [14:45<00:00,  1.30s/it]
# Validating: 100%|██████████| 171/171 [01:26<00:00,  1.98it/s]
# Validation F1 Score: 0.22
# Epoch 3/20: 100%|██████████| 683/683 [14:45<00:00,  1.30s/it]
# Validating: 100%|██████████| 171/171 [01:26<00:00,  1.98it/s]
# Validation F1 Score: 0.27
# Epoch 4/20: 100%|██████████| 683/683 [14:45<00:00,  1.30s/it]
# Validating: 100%|██████████| 171/171 [01:26<00:00,  1.99it/s]
# Validation F1 Score: 0.33
# Epoch 5/20: 100%|██████████| 683/683 [14:45<00:00,  1.30s/it]
# Validating: 100%|██████████| 171/171 [01:26<00:00,  1.98it/s]
# Validation F1 Score: 0.36
# Epoch 6/20: 100%|██████████| 683/683 [14:44<00:00,  1.30s/it]
# Validating: 100%|██████████| 171/171 [01:26<00:00,  1.98it/s]
# Validation F1 Score: 0.40
# Epoch 7/20: 100%|██████████| 683/683 [14:44<00:00,  1.30s/it]
# Validating: 100%|██████████| 171/171 [01:26<00:00,  1.98it/s]
# Validation F1 Score: 0.43
# Epoch 8/20: 100%|██████████| 683/683 [14:44<00:00,  1.30s/it]
# Validating: 100%|██████████| 171/171 [01:26<00:00,  1.98it/s]
# Validation F1 Score: 0.46
# Epoch 9/20: 100%|██████████| 683/683 [14:44<00:00,  1.30s/it]
# Validating: 100%|██████████| 171/171 [01:26<00:00,  1.99it/s]
# Validation F1 Score: 0.47
# Epoch 10/20: 100%|██████████| 683/683 [14:45<00:00,  1.30s/it]
# Validating: 100%|██████████| 171/171 [01:26<00:00,  1.98it/s]
# Validation F1 Score: 0.47
# Epoch 11/20: 100%|██████████| 683/683 [14:45<00:00,  1.30s/it]
# Validating: 100%|██████████| 171/171 [01:26<00:00,  1.98it/s]
# Validation F1 Score: 0.48
# Epoch 12/20: 100%|██████████| 683/683 [14:46<00:00,  1.30s/it]
# Validating: 100%|██████████| 171/171 [01:26<00:00,  1.98it/s]
# Validation F1 Score: 0.47
# Epoch 13/20: 100%|██████████| 683/683 [14:46<00:00,  1.30s/it]
# Validating: 100%|██████████| 171/171 [01:26<00:00,  1.97it/s]
# Validation F1 Score: 0.47
# Early stopping triggered.

# %% [markdown]
# # Inference

# %%
# 테스트 세트 추론
model.eval()
test_predictions = []
with torch.no_grad():
    for batch in tqdm(test_loader, desc='Testing'):
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        outputs = model(input_ids, attention_mask=attention_mask)
        _, preds = torch.max(outputs.logits, dim=1)
        test_predictions.extend(preds.cpu().tolist())

# 라벨 디코딩
label_decoder = {i: label for label, i in label_encoder.items()}
decoded_predictions = [label_decoder[pred] for pred in test_predictions]
# Out:
# Testing: 100%|██████████| 366/366 [03:06<00:00,  1.96it/s]

# %% [markdown]
# # Submission

# %%
sample_submission = pd.read_csv("/content/drive/MyDrive/gbt해커톤/data/sample_submission.csv")
sample_submission["분류"] = decoded_predictions

sample_submission.to_csv("./baseline_kobert.csv", encoding='UTF-8-sig', index=False)
