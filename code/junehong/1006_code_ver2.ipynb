# %% [markdown]
# # Import

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# 한글 폰트 지정
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

font_path = "C:/Windows/Fonts/malgun.ttf"

# %% [markdown]
# # Load Data

# %%
train_df = pd.read_csv("../../data/train_df_translate_del.csv")
test_df = pd.read_csv("../../data/test_df_translate_del.csv")  
submission = pd.read_csv("../../data/sample_submission.csv")

# %%
print(len(test_df))
print(len(submission))
# Out:
# 23405
# 23405

# %%
import pandas as pd

# NaN 값을 찾는 함수
def find_nan_values(df, column_name):
    nan_rows = df[df[column_name].isna()]
    return nan_rows

# train_df와 test_df에서 '키워드' 열의 NaN 값 찾기
nan_train = find_nan_values(train_df, '키워드')
nan_test = find_nan_values(test_df, '키워드')

print("Train DataFrame에서 NaN 값이 있는 행들:")
print(nan_train)

print("\nTest DataFrame에서 NaN 값이 있는 행들:")
print(nan_test)
# Out:
# Train DataFrame에서 NaN 값이 있는 행들:
# Empty DataFrame
# Columns: [ID, 분류, 제목, 키워드]
# Index: []
#
# Test DataFrame에서 NaN 값이 있는 행들:
# Empty DataFrame
# Columns: [ID, 제목, 키워드]
# Index: []

# %% [markdown]
# ## 전처리

# %% [markdown]
# 영어로만 구성된 단어에 대한 처리 (주소 제거)

# %%
import pandas as pd
import re

# 제거할 단어 리스트
remove_words = ['http', 'www.', '.kr', '.net', '.com']

def remove_specific_words(text):
    words = text.split(',')
    filtered_words = [word for word in words if not any(remove_word in word for remove_word in remove_words)]
    return ','.join(filtered_words)

# '키워드' 열에 함수 적용
train_df['키워드'] = train_df['키워드'].apply(remove_specific_words)
test_df['키워드'] = test_df['키워드'].apply(remove_specific_words)

# %%
print(len(test_df))
print(len(submission))
# Out:
# 23405
# 23405

# %%
import pandas as pd
import re

# 영어로만 된 단어를 필터링하는 함수
def is_english(word):
    return bool(re.match('^[a-zA-Z]+$', word))

# 영어로만 된 단어를 추출하는 함수
def extract_english_keywords(keywords):
    words = keywords.split(',')
    english_words = [word for word in words if is_english(word)]
    return english_words

# 모든 영어 단어를 하나의 리스트로 모으기
train_english_words = []
test_english_words = []

train_df['키워드'].apply(lambda x: train_english_words.extend(extract_english_keywords(x)))
test_df['키워드'].apply(lambda x: test_english_words.extend(extract_english_keywords(x)))

# 리스트를 시리즈로 변환하여 value_counts 호출
train_english_word_counts = pd.Series(train_english_words).value_counts()
test_english_word_counts = pd.Series(test_english_words).value_counts()

# 2개 이하로 등장하는 단어 제거
train_words_to_remove = train_english_word_counts[train_english_word_counts <= 2].index.tolist()
test_words_to_remove = test_english_word_counts[test_english_word_counts <= 2].index.tolist()

# 원본 데이터에서 해당 단어들을 제거하는 함수
def remove_infrequent_words(keywords, words_to_remove):
    words = keywords.split(',')
    filtered_words = [word for word in words if word not in words_to_remove]
    return ','.join(filtered_words)

# 원본 데이터에 반영
train_df['키워드'] = train_df['키워드'].apply(lambda x: remove_infrequent_words(x, train_words_to_remove))
test_df['키워드'] = test_df['키워드'].apply(lambda x: remove_infrequent_words(x, test_words_to_remove))

# 상위 10개의 결과 출력
filtered_train_english_word_counts = train_english_word_counts[train_english_word_counts > 2]
filtered_test_english_word_counts = test_english_word_counts[test_english_word_counts > 2]

print("Train DataFrame 상위 10개의 결과:")
print(filtered_train_english_word_counts.head(10))

print("\nTest DataFrame 상위 10개의 결과:")
print(filtered_test_english_word_counts.head(10))
# Out:
# Train DataFrame 상위 10개의 결과:
# AI       3608
# SK       3319
# GTX      2956
# LH       2919
# IC       1842
# SNS      1644
# CCTV     1532
# GH       1510
# KLPGA    1410
# TF       1386
# dtype: int64
#
# Test DataFrame 상위 10개의 결과:
# AI       1575
# SK       1358
# GTX      1275
# LH       1255
# GH        836
# IC        776
# SNS       717
# TF        619
# ESG       613
# KLPGA     579
# dtype: int64

# %%
print(len(test_df))
print(len(submission))
# Out:
# 23405
# 23405

# %% [markdown]
# 영어, 한글 혼합 단어 처리

# %%
import pandas as pd

# 제거할 단어 리스트
remove_words = [
    'http', 'www.', '.kr', '.net', '.com',
    'A씨', 'B씨', 'A양', 'C씨', 'C양', 'D씨', 'A군', 'A사', 'B군', 'B사', 'F팀', 'A업체', 'C노선',
    'B양', 'D등급', 'L자형', 'A의원', 'E씨', 'A그룹', 'A타입', 'C등급', 'B그룹', 'A교사', 'C법인',
    'A선수', 'A법인', 'B등급', 'B노선', 'B타입', 'J씨', 'A시행사', 'A대표', 'G사', 'E등급', 'A경위',
    'B법인', 'R구역', 'A시의원', 'P사', 'K씨', 'C그룹', 'D센터', 'B업체', 'A교회', 'D사', 'H사', 'A아파트',
    'B학생', 'C값', 'F씨', 'S씨', 'C군', 'H공인중개사사무소', 'A캐피탈', 'S등급', 'A고등학교', 'A경사', 'B교회',
    'D법인', 'C사', 'G씨', 'A골프장', 'F노선', 'D노선', 'm가량', 'A팀장', 'L씨', '플랜B', 'B의원', 'A어린이집',
    'S사', 'A농장', 'B지구', 'D구역', 'A산후조리원', 'L사', 'A노래방', 'A사령관', 'Y씨', 'B교사', 'A동', 'C의원',
    'A원장', 'A카페', 'A연구소', 'E주식회사', 'B아파트', 'B어린이집', 'B경장', 'A요양병원', 'F채널', 'A학생',
    'A연습장', 't가량', 'A학원', 'A건설사', 'B동', 'B초등학교', 'B건설사', 'B시장', 'n차', 'p차', 'A식품접객업소',
    'C법', 'B한약국', 'C한약방', 'E군', 't트럭', 'G모사', 'A회사', 'A경찰관', 'A기업', 'B학원', 'C업체',
    'A공인중개사사무소', 'A도시', 'A회장', 'V그룹', 'A고교', 'B동물병원', 'A요양원', 'SA등급', 'B도의원',
    'C변호사', 'B시 B씨네', 'A마트', 'C병원', 'A병원', 'D아파트', 'B공인중개사', 'B선수', 'A협회', 'A사장',
    'D양', 'B개발', 'A조합', 'E노선', '원x2.5', 'A구', 'G그룹', 'S자', 'A공', 'A검사', 'n곤충.kr', 'A팀', '0반',
    'C중학교', 'P차이', 'km가량', 'B조', 'J건설사', 'C컨벤션', 'D건설', 'SS이슈', '시즌A', '시즌B', '시즌C', 'A농협',
    'A약국', 'C약국', 'A구역', '존x', 'A은행', 'kw급', 'D군', 'A헬스장', 'B팀', 'C예식장', 'A단지', 'A지점', 'A지자체',
    't급', 'M교회', 'C블록', 'B목사', '플랜C', 'B번', '개XX', 'D교사', 'B골프장', 'H건설', 'A종합부동산금융사',
    'B세무서장', 'H산업', 'T골프장', 'H씨', 'A강사', 'B강사', 'B원장', 'J기업', 'M타워', 'A현장', 'A소방관', 'C동',
    'F양', 'A초등학생', 'A언론사', 'A당원', 'A시', 'C상병', 'C교수', 'C학원', 'C아파트', 'A등', 'X새끼', 'D구'
]

def remove_exact_words(text):
    words = text.split(',')
    filtered_words = [word for word in words if word not in remove_words]
    return ','.join(filtered_words)

# '키워드' 열에 함수 적용
train_df['키워드'] = train_df['키워드'].apply(remove_exact_words)
test_df['키워드'] = test_df['키워드'].apply(remove_exact_words)

# %%
print(len(test_df))
print(len(submission))
# Out:
# 23405
# 23405

# %%
import pandas as pd
import re

# 영어와 한글이 혼합된 단어를 필터링하는 함수
def is_mixed_korean_english(word):
    return bool(re.search('[a-zA-Z]', word) and re.search('[가-힣]', word))

# 영어와 한글이 혼합된 단어를 추출하는 함수
def extract_mixed_keywords(keywords):
    words = keywords.split(',')
    mixed_words = [word for word in words if is_mixed_korean_english(word)]
    return mixed_words

# 모든 영어와 한글이 혼합된 단어를 하나의 리스트로 모으기
train_mixed_words = []
test_mixed_words = []

train_df['키워드'].apply(lambda x: train_mixed_words.extend(extract_mixed_keywords(x)))
test_df['키워드'].apply(lambda x: test_mixed_words.extend(extract_mixed_keywords(x)))

# 리스트를 시리즈로 변환하여 value_counts 호출
train_mixed_word_counts = pd.Series(train_mixed_words).value_counts()
test_mixed_word_counts = pd.Series(test_mixed_words).value_counts()

# 3개 이하로 등장하는 단어 제거
train_words_to_remove = train_mixed_word_counts[train_mixed_word_counts <= 3].index.tolist()
test_words_to_remove = test_mixed_word_counts[test_mixed_word_counts <= 3].index.tolist()

# 원본 데이터에서 해당 단어들을 제거하는 함수
def remove_infrequent_words(keywords, words_to_remove):
    words = keywords.split(',')
    filtered_words = [word for word in words if word not in words_to_remove]
    return ','.join(filtered_words)

# 원본 데이터에 반영
train_df['키워드'] = train_df['키워드'].apply(lambda x: remove_infrequent_words(x, train_words_to_remove))
test_df['키워드'] = test_df['키워드'].apply(lambda x: remove_infrequent_words(x, test_words_to_remove))

# 상위 10개의 결과 출력
filtered_train_mixed_word_counts = train_mixed_word_counts[train_mixed_word_counts > 3]
filtered_test_mixed_word_counts = test_mixed_word_counts[test_mixed_word_counts > 3]

print("Train DataFrame 상위 10개의 결과:")
print(filtered_train_mixed_word_counts.head(10))

print("\nTest DataFrame 상위 10개의 결과:")
print(filtered_test_mixed_word_counts.head(10))
# Out:
# Train DataFrame 상위 10개의 결과:
# SK하이닉스      4057
# GS건설         511
# DL이앤씨        323
# CJ대한통운       273
# QR코드         269
# D2블록         224
# HL디앤아이한라     214
# R&D센터        200
# LG전자         199
# SK에코플랜트      191
# dtype: int64
#
# Test DataFrame 상위 10개의 결과:
# SK하이닉스      1548
# GS건설         257
# DL이앤씨        133
# CJ대한통운       127
# QR코드         114
# GTX-A노선      101
# D2블록          86
# R&D센터         85
# HL디앤아이한라      82
# A등급           81
# dtype: int64

# %%
print(len(test_df))
print(len(submission))
# Out:
# 23405
# 23405

# %%
import re
from collections import Counter

# 불용어 제거
removed_keywords = []

def remove_invalid_keywords(keywords):
    pattern = re.compile(
        r'[0-9]+[가-힣\u4E00-\u9FFF]+|'     # 숫자+한글
        r'[0-9]+[A-Za-z]+|'                 # 숫자+영어
        r'[가-힣]+[0-9]+|'                  # 한글+숫자
        r'[A-Za-z]+[0-9]+|'                 # 영어+숫자

        r'[\u4E00-\u9FFF]+|'                # 한자
        r'[0-9]+(\.[0-9]+)?%|'              # 숫자+퍼센트
        r'[0-9]+'                          # 숫자
    )
    valid_keywords = []
    exceptions = ['코로나19', 'RE100', 'GS25']
    for word in keywords.split(','):
        word = word.strip()
        if not word or pattern.match(word):  # 공백이거나 패턴에 맞는 단어 제거
            if word not in exceptions:  # 예외 처리
                removed_keywords.append(word)
            else:
                valid_keywords.append(word)
        else:
            valid_keywords.append(word)
    return ', '.join(valid_keywords)

# 원본 데이터에서 해당 키워드들을 제거
train_df['키워드'] = train_df['키워드'].apply(remove_invalid_keywords)
test_df['키워드'] = test_df['키워드'].apply(remove_invalid_keywords)

# 제거된 단어들 출력
print("\n제거된 단어들:")
print(removed_keywords[:10])
# Out:
# 제거된 단어들:
# ['18일', '15일', '7월', '8월', '50%', '22일', '20명', '10명', '70명', '36종류']

# %% [markdown]
# '경기용'과 '전문' 단어 제거

# %%
# '경기용'과 '전문' 단어 제거 함수
def remove_keywords(keywords, words_to_remove):
    keywords_list = keywords.split(', ')
    filtered_keywords = [word for word in keywords_list if word not in words_to_remove]
    return ', '.join(filtered_keywords)

# 제거할 단어 목록
words_to_remove = ['경기용', '전문']

# '키워드' 열 업데이트
train_df['키워드'] = train_df['키워드'].apply(lambda x: remove_keywords(x, words_to_remove))
test_df['키워드'] = test_df['키워드'].apply(lambda x: remove_keywords(x, words_to_remove))

# %%
# 정확히 일치하는 행 필터링
filtered_df = train_df[train_df['키워드'].str.contains(r'ᅳᆯ', na=False)]

# 결과 출력
filtered_df.iloc[0]['키워드']
# Out:
# '김동성, 양육비, 배드파더스, 등재, 평생, 꼬리표, 인민정, 호소, 김동성, 쇼트, 트랙, 국가, 대표, 극단적, 선택, 인민정, 여자, 친구, 인민정, 자신, SNS, 심경, 인스타그램, 저, ᆼ글맘, 자신, 처지, 공개, 우울증, 공황, 장애, 김동성, 공평, 상황들, 뇌리, 장문, 김동성, ᅥᆫ만원정도, 살아야, 로, 고, 그, 꼬리표는, 평생, 달고, 사, 토로, 김동성씨, 방송, ᅳᆯ, 도, 아무것, ᅡᄀ, 스, 써, 여, ᆷᄒ, ᅩᄅ, 데, 극단적, ᅳᆯ, 할, 수밖에, 어, 바닥, 어, 이, 지옥, 상황, 결과, 호소, 김동성, 지난달, 용인시, 상현동, 자택, 극단적, 선택, 시도, 신고, 출동, 대원, 병원, 이송, 생명, 지장, ᅦᄀ, ᅳᆫ, 질타, 않으면, ᆯᄋ, ᅳᆫ데, 저는, 제가, 눈을, 뜨고, 있는, 한, 어떠한, 상황에서도, 발벗고, 나서지, 아, 일분이, 가, 이, 이, 이, 소중하기ᄋ, ᅳᆫ, 야, 설명, 배드파더스, 경제활동, 악의적, 양육비, 비양육자, 채찍질, 소득, 수입, 재산, 비양육자, 배드파더스, 낙인, 합리적, 개인적, 생각, 아내, 이혼, 양육비, 논란, 김동성, TV조선, 이혼, 프로그램, 출연, 인민정, 인스타, 그램, 싱글맘, 양육자와, 비양육자, ᆼ글맘입니다, 지금껏, 양육비ᄂ, 이엄마입니다, 도, ᅳᆯ, 걸까, 이, 이, 서, 이, 벌었습니다, 도, 아, ᅳᆯ, ᅳᆯ, 김동성씨ᄂ, 고, 랴, 로, 이, ᅥᆫ만원정도입니다, 도, 로, 고, 그, 꼬리표는, 평생, 달고, 사, 남자친구, ᅦᄀ, ᅳᆫ, 고, 느, ᆯᄋ, ᅳᆫ데, 저는, 제가, 눈을, 뜨고, 있는한, 어떠한, 상황에서도, 발벗고, 나서지, 않으면, 지금, 우리는, 올ᄉ, ᆼ입니다, 가, 이, 이, 이, ᅳᆫ, 없습니다, 도, 가야합ᄂ, 에, ᅳᆫ, ᅳᆯ, 보며, 공평하지, 못한, 이, 사, 이, ᅳᆯ, 후, 아, ᅳᆯ, 못하고, 이, 과거, 도ᄃ, 했느, ᅡᄀ, 스, 써, 여, ᆷᄒ, ᅩᄅ, 없었던, 이, 이, 으, ᆩᄋ, 어, 바닥으로, 곳ᄋ, 이, 어, ᅳᆫ, 지옥이였습니다, 이런상황ᄋ, ᅪ인걸까요, 생각입니다, 겨, 으, 도, ᅳᆯ, 로, 아, ᅳᆯ, 하되, 아무런, 소득도, 수입도, 재산도, 없는, 비ᄋ, ᅳᆯ, ᅳᆫ, 이, 배드파더스지혜롭게현명하게, 배드파더스ᄀ, ᅦᄀ, 겨, 으, 서, 펴'

# %%
# 해당 행 제거
train_df = train_df.drop(filtered_df.index)

# %%
print(len(test_df))
print(len(submission))
# Out:
# 23405
# 23405

# %%
import pandas as pd

# '키워드' 열의 각 문자열 길이 계산
train_df['키워드_길이'] = train_df['키워드'].apply(len)
test_df['키워드_길이'] = test_df['키워드'].apply(len)

# 길이가 긴 순서대로 정렬하여 상위 5개의 길이 출력 (train_df)
top_5_lengths_train = train_df.nlargest(5, '키워드_길이')['키워드_길이']
print("Top 5 키워드 길이 (Train DataFrame):")
print(top_5_lengths_train)

# 길이가 긴 순서대로 정렬하여 상위 5개의 길이 출력 (test_df)
top_5_lengths_test = test_df.nlargest(5, '키워드_길이')['키워드_길이']
print("\nTop 5 키워드 길이 (Test DataFrame):")
print(top_5_lengths_test)
# Out:
# Top 5 키워드 길이 (Train DataFrame):
# 50050    11637
# 30489    11568
# 6135     10764
# 53513     8899
# 14412     8688
# Name: 키워드_길이, dtype: int64
#
# Top 5 키워드 길이 (Test DataFrame):
# 19921    12816
# 20753     9682
# 7075      8388
# 16362     7619
# 2679      7216
# Name: 키워드_길이, dtype: int64

# %%
# '키워드' 열의 각 문자열에서 쉼표로 구분된 단어의 개수 계산
train_df['단어_개수'] = train_df['키워드'].apply(lambda x: len(x.split(',')))
test_df['단어_개수'] = test_df['키워드'].apply(lambda x: len(x.split(',')))

# 단어 개수를 기준으로 상위 5개의 개수 출력 (train_df)
top_5_word_counts_train = train_df.nlargest(5, '단어_개수')['단어_개수']
print("\nTop 5 단어 개수 (Train DataFrame):")
print(top_5_word_counts_train)

# 단어 개수를 기준으로 상위 5개의 개수 출력 (test_df)
top_5_word_counts_test = test_df.nlargest(5, '단어_개수')['단어_개수']
print("\nTop 5 단어 개수 (Test DataFrame):")
print(top_5_word_counts_test)
# Out:
# Top 5 단어 개수 (Train DataFrame):
# 50050    2606
# 30489    2480
# 14412    1973
# 53513    1952
# 53       1767
#          ...
# 435       330
# 4259      330
# 4650      330
# 5402      330
# 6449      330
# Name: 단어_개수, Length: 3000, dtype: int64
#
# Top 5 단어 개수 (Test DataFrame):
# 19921    2541
# 20753    2056
# 7075     1834
# 16362    1759
# 2679     1641
# Name: 단어_개수, dtype: int64

# %%
# '키워드' 열의 각 문자열에서 쉼표로 구분된 단어의 개수 계산
train_df['단어_개수'] = train_df['키워드'].apply(lambda x: len(x.split(',')))
test_df['단어_개수'] = test_df['키워드'].apply(lambda x: len(x.split(',')))

# 단어 개수를 기준으로 상위 5개의 개수 출력 (train_df)
top_5_word_counts_train = train_df.nlargest(5, '단어_개수')['단어_개수']
print("\nTop 5 단어 개수 (Train DataFrame):")
print(top_5_word_counts_train)

# 단어 개수를 기준으로 상위 5개의 개수 출력 (test_df)
top_5_word_counts_test = test_df.nlargest(5, '단어_개수')['단어_개수']
print("\nTop 5 단어 개수 (Test DataFrame):")
print(top_5_word_counts_test)

# 단어의 개수가 제일 많은 행의 키워드 출력 (train_df)
max_word_count_keyword_train = train_df.loc[train_df['단어_개수'].idxmax(), '키워드']
print("\n단어의 개수가 제일 많은 행의 키워드 (Train DataFrame):")
print(max_word_count_keyword_train)

# 단어의 개수가 제일 많은 행의 키워드 출력 (test_df)
max_word_count_keyword_test = test_df.loc[test_df['단어_개수'].idxmax(), '키워드']
print("\n단어의 개수가 제일 많은 행의 키워드 (Test DataFrame):")
print(max_word_count_keyword_test)
# Out:
# Top 5 단어 개수 (Train DataFrame):
# 50050    2606
# 30489    2480
# 14412    1973
# 53513    1952
# 53       1767
# Name: 단어_개수, dtype: int64
#
# Top 5 단어 개수 (Test DataFrame):
# 19921    2541
# 20753    2056
# 7075     1834
# 16362    1759
# 2679     1641
# Name: 단어_개수, dtype: int64
#
# 단어의 개수가 제일 많은 행의 키워드 (Train DataFrame):
# 총체, 난국, 최후, 발악, 안철수, 오세훈, 희망, 집중, 민주당, 땅투기, DNA, 대통령, 보장, 투기, 이익, 대통령, 근심, 걱정, 공수처, 고위공직자범죄꾼, 상담처, 전락, K-방역, 한명숙, 실체, 컴퓨터, 기생충, 단어, 기생충, 학자, 서민, 교수, 사랑, 애정, 긍정, 의미, 기생충, 대한민국, 정치인, 비유, 생물, 통속, 의미, 기생충, 생각, 기생충, 기생충, 국민, 고혈, 흡혈, 기생충, 국민, 등골, 기생충, 국민, 세금, 백수, 기생충, 정도, 차이, 장내, 미생물, 국민들, 도움, 기생충들, 정치인들, 기생충, 폄하, 외면, 기생충, 세계, 정치판, 민낯, 우여곡절, 갈등, 국민, 안철수, 후보, 양보, 선언, 물꼬, 난관, 오세훈, 국민, 후보, 양보, 사람, 국민정서, 이날, 후보, 양보, 선언, 기분, 촌극, 후보, 서울, 시장, 기생충, 정치판, 국민들, 편안, 말뜻, 정치, 실천, 당부, 정치, 바르다, 회초리, 의미, 등글월문, 건축물, 정치, 자신, 사람, 부조화, 부정적, 극복, 대통령, 정도, 매입, 사저, 경남, 양산, 농지, 대지, 형질, 변경, 확인, 페이스북, 문재인, 대통령, 반응, 대통령, 대통령, 본인, 사저, 부지, 투기, 논란, 사과문, 사람, 부부, 문재인, 대통령, 대통령, 가족, 의혹, 부동산, 투기, 분노, 국민들, 제기, 야당, 사과, 합리적, 해명, 국민, 야당, 문재인, 대통령, 박원순, 서울, 시장, 후보, 유세, 현장, 이명박, 대통령, 사저, 논란, 부지, 대통령, 사저, 의미, 탐욕, 사람들, 욕심, 이명박, 정부, 정치, 이명박, 정부, 정치, 비난, 문재인, 대통령, 사저, 논란, 설명, 국민들, 큰소리, 생각, 방귀, 속담, 사용, 노영민, 대통령, 비서실장, 방송, 라디오, 출연, 부부, 문재인, 대통령, 농지, 취득, 관공서, 경력, 영농, 허위, 주장, 대통령직, 수행, 텃밭, 의미, 영농, 활동, 설명, 농지, 콘크리트, 도로, 대통령, 비서실장, 생각, 주호영, 국민, 원내대표, 문재인, 대통령, 양산, 사저, 만인, 평등, 대통령, 가족, 진행, 농지, 구입, 용도, 변경, 불법, 처벌, 지적, 여당, 의석, 검찰, 법원, 헌법재판소, 언론, 장악, 대통령, 불법, 영농, 비료비, 농약비, 종자비, 묘목비, 영농, 지출내역, 영농, 지출, 내역, 공개, 문재인, 대통령, 목록, 영농, 비용, 제출, 신뢰, 만큼, 실사, 작업, 콘크리트, 도로, 경작, 묘목, 종자, 농약, 문재인, 대통령, 본인, 페이스북, 거짓말, 대통령, 사저, 경호시설, 포함, 마음, 처분, 문재인, 대통령, 해명, 주호영, 원내, 대표, 이야기, 대통령, 경호법, 전직, 경호, 양산, 사저, 국가, 헌납, 이야기, 선거, 시비, 야당, 제기, 사안, 문재인, 대통령, 수석, 청와대, 보좌관, 회의, LH, 사태, 확산, 투기, 논란, 정부, 의지, 결기, 청산, 부동산, 적폐, 투명, 공정, 부동산, 거래, 질서, 확립, 임기, 핵심적, 임기, 핵심, 국정과제, 추진, 적폐청산, 촛불정신, 운운, 주택, 공급, 무주택자들, 청년들, 피해, 정부, 예정, 공급대책, 계획, 차질, 진행, 최선, 국회, 공급, 대책, 뒷받침, 입법, 속도, 서민들, 주거안정, 대통령, 걱정, 서민주거안정, 대통령, 행동, 친화적, 부동산, 투기, 친화, 일관성, 문재인, 대통령, 변창흠, 국토, 교통부, 장관, 사건, LH, 직원, 투기, 사의, 표명, 사의, 수용, 사표, 수리, 대책, 부동산, 차질, 추진, 중요, 작업, 입법, 기초, 마무리, 임기, 남짓, 문재인, 대통령, 수용, 억측, 지역, 주변, 지역, 문재인, 정권, 핵심, 인물, 주변세력들, 투자, 질문, 투기, 세력, 조사, 수사, 능력, 감사원, 검찰, 자진, 신고, 제보, 언론, 보도, 수사, 경찰, 정부합동조사단, 짐작, 부동산건설개혁본부장, 김헌동, 경실련, 부동산, 건설, 개혁, 본부장, 언론, 인터뷰, 문재인, 정권, 성장, 불로, 소득, 주도, 정권, 가짜, 진보, 규정, 김헌동, 본부장, 문재인, 정부, 출범, 부동산, 투기, 조장, LH, 직원, 사건, 의혹, 조사, 국민들, 정부, 가식적, 무능, 지정, 취소, 투기꾼, 손해, 수도, 집값, 안정, 건설, 집값, 투기, 성행, 부작용, 주장, 투기, 사례, 문재인, 대통령, 추진, 집착, 내편, 투기, 이익, 의심, 순간, 정문, 서울, 강남구, 논현동, LH, 서울, 지역, 본부, 정문, 한국청년연대, 청년, 청년진보당, 청년단체들, 좌파, 성향, 청년, 단체, 촛불, 세상, 부동산, 투기, 청년들, 월세, 전전, LH, 투기, 전전, 문구, 피켓, 집회, 문재인, 대통령, 가짜, 촛불, 정신, 운운, 좌파, 청년, 단체, 진짜, 촛불, 대응, 투기꾼, 철회, 국민들, 목소리, 리얼미터, YTN, 의뢰, 조사, 결과, 광명, 시흥, 추가지정, 추가, 지정, 철회, 응답, 인천, 경기, 광주, 전라, 부산, 울산, 경남, 지역, 의견, 지정, 철회, 압도적, 부동산, 투기, 의견, 이념, 중도, 보수, 진보, 지정, 철회, 찬성, 부동산, 투기, 국민들, 분노, 적반하장, 반응, 문재인, 대통령, 사건, LH, 부동산, 투기, 의혹, 생각, 성실, 국민들, 허탈감, 실망, 사과성, 멘트, 공직자들, 부동산, 부패, 시작, 사회, 만연, 부동산, 부패, 사슬, 계기, 사회, 중요, 뿌리, 부동산, 적폐, 청산, 우리나라, 투명, 공정, 사회, 분기점, 자신들, 대통령, 부부, 자신, 자녀, 친인척, 핵심부, 의혹, 부동산, 투기, 말씀, 대통령, 말씀, 얼마, 신뢰, 민주당, 국회의원, 장관, 지자체장, 주변, 부동산, 투자, 의혹, 모친, 양이원영, 의원, 경기, 광명, 김경만, 의원, 아내, 경기, 시흥, 양향자, 의원, 경기, 화성, 서영석, 의원, 경기, 부천, 김주영, 의원, 아버지, 경기, 화성, 아내, 윤재갑, 의원, 경기, 평택, 신도시, 투기, 의혹, 제기, 민주당, 임종성, 의원, 가족, 명단, 투기, 의혹, 추가, 국회의원, 민주당, 현역, 의원, 임종, 민주당, 누나, 사촌, 경기도의원, 보좌관, 출신, 경기도, 의원, 아내, 경기, 광주시, 고산, 택지, 지구, 주변, 공동매입, 임종, 민주당, 의원, 소속, 국회, 국토, 교통위, 투기, 투자, 대표, 친문, 장관, 전해철, 행정안전부, 지역보좌관, 아내, 경기, 안산, 상록구, 장상, 지구, 토지, 정부, 신규, 택지, 추진, 계획, 매입, 안산, 상록, 전해철, 장관, 민주당, 국회의원, 지역구, 절대, 절대, 땅투기, 달만, 신규, 택지, 추진, 계획, 문재인, 대통령, 친구, 송철호, 울산, 시장, 절대, 땅투기, 송철호, 울산, 시장, 변호사, 활동, 배우자, 경기도, 용인시, 임야, 매입, 언론, 보도, 투기, 해명, 개발이익, 투자, 주장, 개발손해, 투자, 대통령, 친구분, 질문, 공수처, 실체, 고위공직자범죄수사처, 공수처, 김학의, 사건, 법무부, 차관, 불법, 출금, 검찰, 재이첩, 수사, 사건, 공수처, 송치, 공문, 확인, 수사, 검찰, 기소, 여부, 공수처, 결정, 공수처, 공수처법, 고위, 공직자, 범죄, 공소, 제기, 유지, 업무, 범위, 명시, 여부, 만큼, 기소, 자신들, 결정, 주장, 법조계, 규정, 공수처, 업무, 범위, 기소, 권한, 공수처, 기소, 법령, 왜곡, 지적, 김진욱, 공수처장, 언론, 통화, 수사, 권한, 이첩, 기소, 권한, 이첩, 김학의, 수사, 법무부, 차관, 불법, 출금, 의혹, 이정섭, 수원지검, 형사, 부장, 검찰, 내부망, 이프로스, 공수처장, 사건, 재이첩, 공문, 수사완료, 공수처, 기소, 여부, 판단, 사건, 송치, 수사, 지휘, 문구, 떡하, 기재, 질문, 수습, 사건, 이첩, 수사권한, 이첩, 해괴망칙, 논리, 비판, 이정섭, 부장, 검사, 이첩, 특정, 기관, 사건, 기관, 기관, 처리, 행위, 공수처, 수사기관, 사건, 이첩, 수사기관, 사건, 관여, 권한, 공수처, 수사기관, 사건, 이첩, 관여, 권한, 설명, 법률, 전문가, 김진욱, 공수처장, 주장, 이정섭, 부장, 검사, 설명, 설득력,  ...
#
# 단어의 개수가 제일 많은 행의 키워드 (Test DataFrame):
# 인천일보, 창간, 주년, 축하, 분들, 윤석열, 대한민국, 대통령, 유정복, 인천, 광역, 시장, 김동연, 경기도, 지사, 이희범, 부영그룹, 회장, 이재명, 더불어민주당, 대표, 허식, 인천시, 의회, 의장, 도성훈, 인천시, 교육감, 배준영, 국민, 국민, 인천광역시당, 위원장, 김교흥, 더불어민주당, 인천광역시당, 위원장, 임종성, 더불어민주당, 경기도당, 위원장, 박용렬, 대한노인회, 인천연합회, 회장, 이종한, 대한노인회, 경기도연합회, 회장, 허종식, 더불어민주당, 인천, 동구미추홀구갑, 국회의원, 윤상현, 인천, 동구미추홀구, 국회의원, 정일영, 더불어민주당, 인천, 연수구, 국회의원, 맹성규, 더불어민주당, 인천, 남동구, 국회의원, 윤관석, 인천, 남동구, 국회의원, 이성, 서구, 인천, 부평구, 국회의원, 유동수, 더불어민주당, 인천, 계양구갑, 국회의원, 신동근, 더불어민주당, 인천, 국회의원, 배진교, 정의당, 국회의원, 양기대, 더불어민주당, 경기, 광명시, 의정부시, 국회의원, 김민철, 국회의원, 양이원영, 더불어민주당, 비례, 대표, 국회의원, 이학영, 국회의원, 이동주, 더불어민주당, 국회의원, 홍기원, 국회의원, 이동환, 고양, 특례, 시장, 이재준, 수원, 특례, 시장, 박종효, 병택, 시흥, 시장, 이민근, 안산, 시장, 김동근, 의정부시장, 김경일, 파주, 시장, 조용익, 부천시장, 박승원, 광명, 시장, 김경희, 이천, 시장, 이충우, 여주, 시장, 김병수, 김포시장, 백경현, 구리시장, 강수현, 양주, 시장, 하은호, 군포시장, 정장선, 평택시장, 이권재, 오산, 시장, 신계, 과천, 시장, 최대호, 안양시장, 박형덕, 동두천시장, 김성제, 의왕시장, 정명근, 화성시장, 신상진, 성남, 시장, 이현재, 하남, 시장, 주광덕, 남양주, 시장, 김정헌, 인천, 중구청장, 김찬진, 인천, 동구청장, 이영훈, 인천, 이재호, 인천, 연수구청장, 인천, 남동구청장, 윤환, 인천, 계양구청장, 강범석, 인천, 서구청장, 유천호, 강화, 군수, 문경복, 옹진, 군수, 김덕현, 연천, 군수, 임호균, 을지대학교, 교수, 김경기, 인천, 웨이브스, 단장, 계기범, 인천고등학교, 야구부, 감독, 김학용, 인천, 야구, 발전, 위원장, 정원배, 인하대학교, 야구부, 감독, 고순선, ㈜동산토탈코팅, 회장, 동산고, 한일은행, 야구, 투수, 김충회, 야구, 원로, 송인택, 연수구, 체육회, 고문, 위원, 서대종, 연수구, 체육회, 고문, 조용준, 경제, 국민의힘, 저자, ㆍKBO, 자문, 위원, 노주현, 인천일보, 홍보, 대사, 정승연, 국민, 의힘, 인천연수구, 당협, 위원장, 강창규, 국민, 인천, 부평, 대변, 당협, 위원장, 신창현, 진보당, 인천광역시당, 위원장, 용혜랑, 진보당, 인천광역시당, 김응호, 정의당, 인천, 부평구, 위원장, 정의당, 부대표, 심재돈, 국민, 동구미추홀구갑, 당협, 위원장, 최진학, 국민, 국민, 군포당, 협위원장, 장영하, 인천광역시, 성남수정구, 당협, 위원장, 염태영, 경기도, 경제, 부지사, 오병, 경기도, 행정, 부지사, 오후석, 경기도, 행정, 부지사, 박덕수, 인천광역시, 행정, 부시장, 이행숙, 인천광역시, 문화, 복지, 정무, 부시장, 고주룡, 대변, 대변, 김진욱, 경기도, 임관, 인천시의회, 건설, 교통, 위원장, 박종혁, 인천시, 의회, 부의장, 김종배, 인천시의회, 건설, 교통, 위원, 신영희, 인천시, 의회, 행정, 안전, 위원, 유승분, 인천시의회, 건설, 교통, 위원, 이용창, 인천시의회, 건설, 교통, 위원, 이인교, 인천시의회, 건설, 교통부, 위원장, 송미희, 시흥시의회, 의장, 송바우, 의장, 안산시의회, 의장, 김영식, 고양, 특례시, 의회, 의장, 이길호, 군포시의회, 의장, 유승영, 평택시, 의회, 의장, 김진웅, 과천시, 의회, 의장, 성길용, 오산시의회, 의장, 강성삼, 하남시, 의회, 의장, 최병일, 안양시의회, 김학기, 의왕시의회, 의장, 박광순, 성남시의회, 의장, 김기정, 수원시의회, 의장, 이재식, 수원, 특례시, 의회, 부의장, 박혜숙, 의왕시의회, 부의장, 강후공, 인천, 중구, 의회, 의장, 오용환, 인천, 남동구의회, 의장, 이정순, 인천, 남동구의회, 의원, 김숙희, 인천, 부평구의회, 행정, 복지, 위원장, 윤구영, 인천, 부평구의회, 의원, 박현주, 인천, 연수구의회, 의원, 김창원, 경인교육대학교, 총장, 이남식, 인천재능대학교, 총장, 조명우, 인하대학교, 총장, 이인재, 인천대학교, 대외, 협력, 부총장, 박명순, 경인여자대학교, 총장, 한태준, 겐트대학교, 의무부총장, 글로벌, 캠퍼스, 총장, 이택, 인하대학교의료원, 의무, 부총장, 의료원장, 이길여, 가천대학교, 총장, 김동원, 인천대학교, 대외, 협력, 처장, 김종호, 인천대, 홍보, 팀장, 김웅희, 인하대학교, 대외, 부총장, 심재선, 인천상공회의소, 회장, 강국창, 인천경영자총협회, 회장, 서임순, 한국여성경제인협회, 인천, 지회, 회장, 황현배, 중소기업중앙회, 인천중소기업회, 회장, 서동만, 인천벤처기업협회, 회장, 최동례, 인천여성단체협의회, 회장, 이영재, 남동, 국가, 산업, 단지, 경영자, 협의회, 회장, 임남례, 한국여성, CEO, 협회, 명예, 회장, 회장, 장섭, 대한건축사협회, 인천광역시, 건축, 사회, 회장, 황규철, 인천, 사랑, 운동, 시민, 협의회, 회장, 박선원, 인천광역시, 사회복지협의회, 회장, 조상범, 법무부, 범죄, 예방, 인천지역협의회, 인천사회복지공동모금회, 이경자, 회장, 김창남, 대한적십자사, 인천광역시지사, 회장, 김형년, 인천시, 재향, 군인회, 회장, 김재업, 인천예총, 회장, 신동욱, 인천광역시, 문화원, 연합회, 회장, 이규생, 인천시체육회, 회장, 신한용, 인하대학교총동창회, 회장, 원용휘, 인천경영포럼, 회장, 신현옥, 한국, 치매, 미술, 치료, 협회, 회장, 김도현, 인하체육인회, 회장, 대한노인회, 인천연합회, 연수구, 지회장, 황명화, 한국여성유권자, 인천연맹, 회장, 이명재, 인천중소경영인연합회, 회장, 김낙형, 한국, OB, 축구회, 인천지, 회장, 길종성, 사단, 법인, 영토, 지킴이독도, 사랑회, 중앙회장, 이장수, 남동구, 지속, 가능, 발전, 협의회, 상임, 회장, 오승한, 인천, 주니어, 클럽, 회장, 이원성, 경기도체육회, 회장, 김종흠, 부천상공회의소, 회장, 박성철, 김포시전문건설인협회, 회장, 이재정, 대한적십자사, 경기도, 지사, 회장, 김식원, KBIZ, 중소기업중앙회, 경기, 회장, 신항철, 경기일보, 대표, 이사, 회장, 권오륜, 현대일보, 회장, 대표이사, 유중호, 인천언론인클럽, 회장, 김민기, 인천언론인클럽, 명예, 회장, 박희제, 인천언론인클럽, 명예, 회장, 박민서, 인천일보, 대표, 이사, 인천스페셜올림픽코리아, 대표이사, 회장, 이영재, 경인일보, 인천본사, 사장, 한창원, 기호일보, 사장, 최윤정, 중부일보, 대표, 이사, 박길상, 인천일보, 대표, 이사, 인천투데이, 회장, 대표, 이사, 김정섭, 인천일보, 변호사, 조우성, 조우성, 인천일보, 주필, 인천시립박물관장, 홍원표, 중부지국장, 일동, 인천일보, 문화, 경영, 대학, 원우, 일동, 인천일보, 자문, 위원회, 회원, 일동, 박병진, 인천일보, 자문위원회장, 회장, 김주형, 인천일보, 경기, 자문, 위원회장, 수원시, 호남향우회, 연합회장, 우종석, 인천일보, 파주, 자문, 위원회, 위원장, 케이엠종합개발, 대표, 장준용, 인천일보, 하남, 자문, 위원장, 하남교산지구원주민재정착위원장, 해양경찰청장ㆍ치, 정상구, 옹진군, 부군수, 권택수, 옹진군, 홍보, 미디어, 팀장, 엄준욱, 인천, 소방본부, 본부장, 김호진, 인천, 소방본부, 소방, 홍보, 팀장, 정혁재, 인천, 소방본부, 소방, 홍보, 주임, 김종욱, 해양, 경찰청장, ㆍ치, 안총감, 김범수, 인천경제자유구역청, 기획, 조정, 본부장, 김은효, 인천경제자유구역청, 미디어, 홍보과장, 김남우, 인천경제자유구역청, 총괄, 비서, 이규성, 수도, 매립지관리공사, 사장, 직무, 대행, 조은경, 수도, 매립지관리공사, 수도권, 홍보 ...

# %%
train_df.drop(columns=['키워드_길이'], inplace=True)
test_df.drop(columns=['키워드_길이'], inplace=True)

# %%
# import os
# import pandas as pd
# from datetime import datetime

# # 현재 날짜 가져오기 (MMDD 형식)
# current_date = datetime.now().strftime('%m%d')

# # CSV 파일명 생성
# train_csv_filename = f"train_df_{current_date}.csv"
# test_csv_filename = f"test_df_{current_date}.csv"

# # CSV 파일로 저장
# train_df.to_csv(train_csv_filename, index=False, encoding='utf-8-sig')
# test_df.to_csv(test_csv_filename, index=False, encoding='utf-8-sig')

# print(f"train_df saved as {train_csv_filename}")
# print(f"test_df saved as {test_csv_filename}")
# Out:
# train_df saved as train_df_1006.csv
# test_df saved as test_df_1006.csv

# %% [markdown]
# .
